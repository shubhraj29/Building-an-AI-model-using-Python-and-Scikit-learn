# %%
# installing necessary libraries

# !pip install numpy
# !pip install seaborn
# !pip install scikit-learn
# !pip install tqdm seaborn skillsnetwork scikit-plot
# Out:
# Requirement already satisfied: numpy in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (1.24.3)
# Requirement already satisfied: seaborn in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tqdm in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (4.65.0)
# Requirement already satisfied: seaborn in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (0.12.2)
# Requirement already satisfied: skillsnetwork in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (0.20.6)
# Requirement already satisfied: scikit-plot in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (0.3.7)
# Requirement already satisfied: colorama in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: ipython in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from skillsnetwork) (8.12.0)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from skillsnetwork) (7.8.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from skillsnetwork) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-plot) (1.3.0)
# Requirement already satisfied: scipy>=0.9 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-plot) (1.10.1)
# Requirement already satisfied: joblib>=0.10 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-plot) (1.2.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (1.1.7)
# Requirement already satisfied: backcall in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: decorator in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from requests<3,>=2->skillsnetwork) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from requests<3,>=2->skillsnetwork) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: executing in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: jinja2 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (7.4.9)
# Requirement already satisfied: nbformat in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.5)
# Requirement already satisfied: entrypoints in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.2.2)
# Requirement already satisfied: lxml in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.12.2)
# Requirement already satisfied: bleach in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.6.7)
# Requirement already satisfied: psutil in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.4)
# Requirement already satisfied: webencodings in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\subhra jyotsna\anaconda3\anacoda files\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.21)

# %%
# importing necessary libraries

from tqdm import tqdm
import skillsnetwork
import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import scikitplot as skplt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# classification model
# task is to classify whether a given customer's probability of churn will be high, medium, or low
# data is available to us in the form of a .csv file and is imported using the pandas library
# we use numpy and matplotlib to get some statistics and visualize data

await skillsnetwork.download_dataset('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX056YEN/churn.csv')
df_churn_pd = pd.read_csv('churn.csv')

df_churn_pd.head()
# Out:
# Downloading churn.csv:   0%|          | 0/164241 [00:00<?, ?it/s]
# Saved as 'churn.csv'
#      ID CHURNRISK GENDER STATUS  CHILDREN  ESTINCOME HOMEOWNER  AGE  \
# 0  1703    Medium    NaN      M         2    28766.9         N   47
# 1  1704       Low    NaN      M         2    91272.2         Y   25
# 2  1705       Low    NaN      S         0    73228.3         N   42
# 3  1706      High      M      M         1    64792.3         N   52
# 4  1707      High      F      S         0    93322.1         Y   40
#
#    TOTALDOLLARVALUETRADED  TOTALUNITSTRADED  LARGESTSINGLETRANSACTION  \
# 0                 6110.61                58                 1527.6525
# 1                26992.70                13                13496.3500
# 2                22472.25                28                11236.1250
# 3                13051.31                36                 6525.6550
# 4                29922.99                 8                14961.4950
#
#    SMALLESTSINGLETRANSACTION  PERCENTCHANGECALCULATION  DAYSSINCELASTLOGIN  \
# 0                  152.76525                      8.70                   2
# 1                 1349.63500                      3.25                   4
# 2                 1123.61250                      7.00                   4
# 3                  652.56550                      9.00                   3
# 4                 1496.14950                      2.00                   4
#
#    DAYSSINCELASTTRADE  NETREALIZEDGAINS_YTD  NETREALIZEDLOSSES_YTD
# 0                  13                0.0000              152.76525
# 1                  10             1349.6350                0.00000
# 2                   5             1123.6125                0.00000
# 3                   6                0.0000              652.56550
# 4                   9                0.0000             1496.14950

# %%
df_churn_pd.shape
# Out:
# (2066, 17)

# %%
# displaying the data type each column is and also the number of entries in each of these columns

print("The dataset contains columns of the following data types : \n" + str(df_churn_pd.dtypes))
# Out:
# The dataset contains columns of the following data types :
# ID                             int64
# CHURNRISK                     object
# GENDER                        object
# STATUS                        object
# CHILDREN                       int64
# ESTINCOME                    float64
# HOMEOWNER                     object
# AGE                            int64
# TOTALDOLLARVALUETRADED       float64
# TOTALUNITSTRADED               int64
# LARGESTSINGLETRANSACTION     float64
# SMALLESTSINGLETRANSACTION    float64
# PERCENTCHANGECALCULATION     float64
# DAYSSINCELASTLOGIN             int64
# DAYSSINCELASTTRADE             int64
# NETREALIZEDGAINS_YTD         float64
# NETREALIZEDLOSSES_YTD        float64
# dtype: object

# %%
# displaying the number of records in each column

print("The dataset contains following number of records for each of the columns: \n" +str(df_churn_pd.count()))
# Out:
# The dataset contains following number of records for each of the columns:
# ID                           2066
# CHURNRISK                    2066
# GENDER                       2063
# STATUS                       2066
# CHILDREN                     2066
# ESTINCOME                    2066
# HOMEOWNER                    2066
# AGE                          2066
# TOTALDOLLARVALUETRADED       2066
# TOTALUNITSTRADED             2066
# LARGESTSINGLETRANSACTION     2066
# SMALLESTSINGLETRANSACTION    2066
# PERCENTCHANGECALCULATION     2066
# DAYSSINCELASTLOGIN           2066
# DAYSSINCELASTTRADE           2066
# NETREALIZEDGAINS_YTD         2066
# NETREALIZEDLOSSES_YTD        2066
# dtype: int64

# %%
# plotting a basic bar chart using matplotlib to understand how data is split between the different output classes
# if we are not satisfied with the representational data, now is the time to get more data to be used for training and testing

print("Each category within the churnrisk column has the following count : ")
print(df_churn_pd.groupby(['CHURNRISK']).size())

#bar chart to show split of data
index = ['High', 'Medium', 'Low']
churn_plot = df_churn_pd['CHURNRISK'].value_counts(sort=True, ascending=False).plot(kind='bar',
            figsize=(4,4), title="Total number for occurences of churn risk "
            + str(df_churn_pd['CHURNRISK'].count()), color=['#BB6B5A', '#8CCB9B', '#E5E88B'])
churn_plot.set_xlabel("Churn Risk")
churn_plot.set_ylabel("Frequency")
# Out:
# Each category within the churnrisk column has the following count :
# CHURNRISK
# High      983
# Low       699
# Medium    384
# dtype: int64
# Text(0, 0.5, 'Frequency')

# %%
# data preprocessing
# data preprocessing is an important step in the machine learning model building process because the model can perform well only when the data it is trained on is good and well prepared
# we begin by identifying columns that will not add any value toward predicting the outputs
# removing such columns helps in reducing dimensionality of the model

# remove columns that are not required

df_churn_pd = df_churn_pd.drop(['ID'], axis=1)
df_churn_pd.head()
# Out:
#   CHURNRISK GENDER STATUS  CHILDREN  ESTINCOME HOMEOWNER  AGE  \
# 0    Medium    NaN      M         2    28766.9         N   47
# 1       Low    NaN      M         2    91272.2         Y   25
# 2       Low    NaN      S         0    73228.3         N   42
# 3      High      M      M         1    64792.3         N   52
# 4      High      F      S         0    93322.1         Y   40
#
#    TOTALDOLLARVALUETRADED  TOTALUNITSTRADED  LARGESTSINGLETRANSACTION  \
# 0                 6110.61                58                 1527.6525
# 1                26992.70                13                13496.3500
# 2                22472.25                28                11236.1250
# 3                13051.31                36                 6525.6550
# 4                29922.99                 8                14961.4950
#
#    SMALLESTSINGLETRANSACTION  PERCENTCHANGECALCULATION  DAYSSINCELASTLOGIN  \
# 0                  152.76525                      8.70                   2
# 1                 1349.63500                      3.25                   4
# 2                 1123.61250                      7.00                   4
# 3                  652.56550                      9.00                   3
# 4                 1496.14950                      2.00                   4
#
#    DAYSSINCELASTTRADE  NETREALIZEDGAINS_YTD  NETREALIZEDLOSSES_YTD
# 0                  13                0.0000              152.76525
# 1                  10             1349.6350                0.00000
# 2                   5             1123.6125                0.00000
# 3                   6                0.0000              652.56550
# 4                   9                0.0000             1496.14950

# %%
# Defining the categorical columns

categoricalColumns = ['GENDER', 'STATUS', 'HOMEOWNER']

print("Categorical columns : ")
print(categoricalColumns)

impute_categorical = SimpleImputer(strategy="most_frequent")

onehot_categorical = OneHotEncoder(handle_unknown='ignore')

categorical_transformer = Pipeline(steps=[('impute', impute_categorical), ('onehot', onehot_categorical)])
# Out:
# Categorical columns :
# ['GENDER', 'STATUS', 'HOMEOWNER']

# %%
# Defining the numerical columns

numericalColumns = df_churn_pd.select_dtypes(include=[float,int]).columns

print("Numerical columns : " )
print(numericalColumns)

scaler_numerical = StandardScaler()

numerical_transformer = Pipeline(steps=[('scale', scaler_numerical)])
# Out:
# Numerical columns :
# Index(['CHILDREN', 'ESTINCOME', 'AGE', 'TOTALDOLLARVALUETRADED',
#        'TOTALUNITSTRADED', 'LARGESTSINGLETRANSACTION',
#        'SMALLESTSINGLETRANSACTION', 'PERCENTCHANGECALCULATION',
#        'DAYSSINCELASTLOGIN', 'DAYSSINCELASTTRADE', 'NETREALIZEDGAINS_YTD',
#        'NETREALIZEDLOSSES_YTD'],
#       dtype='object')

# %%
# transforming data into temporary variable

preprocessorForCategoricalColumns = ColumnTransformer(transformers=[('cat', categorical_transformer,
                                                                    categoricalColumns) ],
                                            remainder="passthrough" )
preprocessorForAllColumns = ColumnTransformer(transformers=[('cat', categorical_transformer, categoricalColumns),
                                                            ('num', numerical_transformer, numericalColumns) ],
                                                remainder="passthrough" )

#. The transformation happens in the pipeline. Temporarily done here to show what intermediate value looks like
df_churn_pd_temp = preprocessorForCategoricalColumns.fit_transform(df_churn_pd)

print("Data after transforming :")

print(df_churn_pd_temp)

df_churn_pd_temp_2 = preprocessorForAllColumns.fit_transform(df_churn_pd)
print("Data after transforming :")
print(df_churn_pd_temp_2)
# Out:
# Data after transforming :
# [[1.0 0.0 0.0 ... 13 0.0 152.76525]
#  [1.0 0.0 0.0 ... 10 1349.635 0.0]
#  [1.0 0.0 0.0 ... 5 1123.6125 0.0]
#  ...
#  [1.0 0.0 0.0 ... 11 0.0 82.50825]
#  [1.0 0.0 0.0 ... 5 930.093 0.0]
#  [0.0 1.0 0.0 ... 8 1041.604 0.0]]
# Data after transforming :
# [[1.0 0.0 0.0 ... -0.6792731303453047 -0.5106065181930338 'Medium']
#  [1.0 0.0 0.0 ... 1.8354629319820521 -0.7959345330293706 'Low']
#  [1.0 0.0 0.0 ... 1.4143217110983428 -0.7959345330293706 'Low']
#  ...
#  [1.0 0.0 0.0 ... -0.6792731303453047 -0.6418293606808149 'Medium']
#  [1.0 0.0 0.0 ... 1.053742394902809 -0.7959345330293706 'Low']
#  [0.0 1.0 0.0 ... 1.261517632686496 -0.7959345330293706 'Low']]

# %%
# preparing data frame for splitting data into train and test datasets

features = []
features = df_churn_pd.drop(['CHURNRISK'], axis=1)

label_churn = pd.DataFrame(df_churn_pd, columns = ['CHURNRISK'])
label_encoder = LabelEncoder()
label = df_churn_pd['CHURNRISK']

label = label_encoder.fit_transform(label)
print("Encoded value of Churnrisk after applying label encoder : " + str(label))
# Out:
# Encoded value of Churnrisk after applying label encoder : [2 1 1 ... 2 1 1]

# %%
# 2D and 3D view of Churnrisk data

area = 75
x = df_churn_pd['ESTINCOME']
y = df_churn_pd['DAYSSINCELASTTRADE']
z = df_churn_pd['TOTALDOLLARVALUETRADED']

pop_a = mpatches.Patch(color='#BB6B5A', label='High')
pop_b = mpatches.Patch(color='#E5E88B', label='Medium')
pop_c = mpatches.Patch(color='#8CCB9B', label='Low')
def colormap(risk_list):
    cols=[]
    for l in risk_list:
        if l==0:
            cols.append('#BB6B5A')
        elif l==2:
            cols.append('#E5E88B')
        elif l==1:
            cols.append('#8CCB9B')
    return cols

fig = plt.figure(figsize=(12,6))
fig.suptitle('2D and 3D view of churnrisk data')

# First subplot
ax = fig.add_subplot(1, 2,1)

ax.scatter(x, y, alpha=0.8, c=colormap(label), s= area)
ax.set_ylabel('DAYS SINCE LAST TRADE')
ax.set_xlabel('ESTIMATED INCOME')

plt.legend(handles=[pop_a,pop_b,pop_c])

# Second subplot
ax = fig.add_subplot(1,2,2, projection='3d')

ax.scatter(z, x, y, c=colormap(label), marker='o')

ax.set_xlabel('TOTAL DOLLAR VALUE TRADED')
ax.set_ylabel('ESTIMATED INCOME')
ax.set_zlabel('DAYS SINCE LAST TRADE')

plt.legend(handles=[pop_a,pop_b,pop_c])

plt.show()

# %%
# data modeling
# splitting data for training and testing
# we are using 98% of the data for training and 2% of the data for testing

X_train, X_test, y_train, y_test = train_test_split(features, label, random_state=0)
print("Dimensions of datasets that will be used for training : Input features" + str(X_train.shape) + " Output label" + str(y_train.shape))
print("Dimensions of datasets that will be used for testing : Input features" + str(X_test.shape) + " Output label" + str(y_test.shape))
# Out:
# Dimensions of datasets that will be used for training : Input features(1549, 15) Output label(1549,)
# Dimensions of datasets that will be used for testing : Input features(517, 15) Output label(517,)

# %%
# preparing a classification model
# random forest classifier by initializing the library provided by Sklearn

model_name = "Random Forest Classifier"

randomForestClassifier = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)

# %%
# assembling the steps using pipeline

rfc_model = Pipeline(steps=[('preprocessorAll', preprocessorForAllColumns), ('classifier', randomForestClassifier)])

# %%
# training the model

# Build models

rfc_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessorAll',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['GENDER', 'STATUS',
#                                                    'HOMEOWNER']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['CHILDREN', 'ESTINCOME', 'AGE', 'TOTALDOLLARVALUETRADED',
#        'TOTALUNITSTRADED', 'LARGESTSINGLETRANSACTION',
#        'SMALLESTSINGLETRANSACTION', 'PERCENTCHANGECALCULATION',
#        'DAYSSINCELASTLOGIN', 'DAYSSINCELASTTRADE', 'NETREALIZEDGAINS_YTD',
#        'NETREALIZEDLOSSES_YTD'],
#       dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=2, random_state=0))])

# %%
# running predictions on the model

y_pred_rfc = rfc_model.predict(X_test)

# %%
# evaluating and visualizing model performance
# True Positive (TP) - label is positive and prediction is also positive
# True Negative (TN) - label is negative and prediction is also negative
# False Positive (FP) - label is negative but prediction is positive
# False Negative (FN) - label is positive but prediction is negative
# helper Methods for Graph Generation

def colormap(risk_list):
    cols=[]
    for l in risk_list:
        if l==0:
            cols.append('#BB6B5A')
        elif l==2:
            cols.append('#E5E88B')
        elif l==1:
            cols.append('#8CCB9B')
    return cols

def two_d_compare(y_test,y_pred,model_name):
    #y_pred = label_encoder.fit_transform(y_pred)
    #y_test = label_encoder.fit_transform(y_test)
    area = (12 * np.random.rand(40))**2 
    plt.subplots(ncols=2, figsize=(10,4))
    plt.suptitle('Actual vs Predicted data : ' +model_name + '. Accuracy : %.2f' % accuracy_score(y_test, y_pred))

    plt.subplot(121)
    plt.scatter(X_test['ESTINCOME'], X_test['DAYSSINCELASTTRADE'], alpha=0.8, c=colormap(y_test))
    plt.title('Actual')
    plt.legend(handles=[pop_a,pop_b,pop_c])

    plt.subplot(122)
    plt.scatter(X_test['ESTINCOME'], X_test['DAYSSINCELASTTRADE'],alpha=0.8, c=colormap(y_pred))
    plt.title('Predicted')
    plt.legend(handles=[pop_a,pop_b,pop_c])

    plt.show()
    
x = X_test['TOTALDOLLARVALUETRADED']
y = X_test['ESTINCOME']
z = X_test['DAYSSINCELASTTRADE']

pop_a = mpatches.Patch(color='#BB6B5A', label='High')
pop_b = mpatches.Patch(color='#E5E88B', label='Medium')
pop_c = mpatches.Patch(color='#8CCB9B', label='Low')

def three_d_compare(y_test,y_pred,model_name):
    fig = plt.figure(figsize=(12,10))
    fig.suptitle('Actual vs Predicted (3D) data : ' +model_name + '. Accuracy : %.2f' % accuracy_score(y_test, y_pred))
    
    ax = fig.add_subplot(121, projection='3d')
    ax.scatter(x, y, z, c=colormap(y_test), marker='o')
    ax.set_xlabel('TOTAL DOLLAR VALUE TRADED')
    ax.set_ylabel('ESTIMATED INCOME')
    ax.set_zlabel('DAYS SINCE LAST TRADE')
    plt.legend(handles=[pop_a,pop_b,pop_c])
    plt.title('Actual')

    ax = fig.add_subplot(122, projection='3d')
    ax.scatter(x, y, z, c=colormap(y_pred), marker='o')
    ax.set_xlabel('TOTAL DOLLAR VALUE TRADED')
    ax.set_ylabel('ESTIMATED INCOME')
    ax.set_zlabel('DAYS SINCE LAST TRADE')
    plt.legend(handles=[pop_a,pop_b,pop_c])
    plt.title('Predicted')

    plt.show()
    

def model_metrics(y_test,y_pred):
    print("Decoded values of Churnrisk after applying inverse of label encoder : " + str(np.unique(y_pred)))

    skplt.metrics.plot_confusion_matrix(y_test,y_pred,text_fontsize="small",cmap='Greens',figsize=(6,4))
    plt.show()
    
    print("The classification report for the model : \n\n"+ classification_report(y_test, y_pred))

# %%
# 2D and 3D visualization of results

two_d_compare(y_test, y_pred_rfc, model_name)
              
three_d_compare(y_test,y_pred_rfc,model_name)

# %%
# confusion matrix

y_test = label_encoder.inverse_transform(y_test)
y_pred_rfc = label_encoder.inverse_transform(y_pred_rfc)
model_metrics(y_test, y_pred_rfc)
# Out:
# Decoded values of Churnrisk after applying inverse of label encoder : ['High' 'Low' 'Medium']
# The classification report for the model :
#
#               precision    recall  f1-score   support
#
#         High       0.86      1.00      0.92       251
#          Low       0.99      1.00      0.99       170
#       Medium       1.00      0.54      0.70        96
#
#     accuracy                           0.91       517
#    macro avg       0.95      0.85      0.87       517
# weighted avg       0.93      0.91      0.91       517

# %%
# comparative study

uniqueValues, occurCount = np.unique(y_test, return_counts=True)
frequency_actual = (occurCount[0],occurCount[2],occurCount[1])

uniqueValues, occurCount = np.unique(y_pred_rfc, return_counts=True)
frequency_predicted_rfc = (occurCount[0],occurCount[2],occurCount[1])

n_groups = 3
fig, ax = plt.subplots(figsize=(10,5))
index = np.arange(n_groups)
bar_width = 0.1
opacity = 0.8

rects1 = plt.bar(index, frequency_actual, bar_width,
alpha=opacity,
color='g',
label='Actual')

rects6 = plt.bar(index + bar_width, frequency_predicted_rfc, bar_width,
alpha=opacity,
color='purple',
label='Random Forest - Predicted')

plt.xlabel('Churn Risk')
plt.ylabel('Frequency')
plt.title('Actual vs Predicted frequency.')
plt.xticks(index + bar_width, ('High', 'Medium', 'Low'))
plt.legend()

plt.tight_layout()
plt.show()
